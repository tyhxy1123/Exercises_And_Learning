# %%
import math
import sys
import random


def codes_with_routes(codes):
    """
    returns the routes for the given codes, specified in routes.dat
    :param codes: the codes for which routes should be extracted
    :return: set of codes with
    """
    route_codes = set([])
    for line in open("routes.dat", encoding='utf-8'):
        split = line.split(",")
        fr = split[2].strip("\"")
        to = split[4].strip("\"")
        if fr in codes and to in codes:
            route_codes.add(fr)
            route_codes.add(to)
    return route_codes


def codes_with_airport_info():
    """
    parse all codes from airports.dat that have all required airport information

    :return: set of codes with complete airport information
    """
    codes = set([])
    for line in open("airports.dat", encoding='utf-8'):
        split = line.split(",")
        if len(split) == 12:
            code = split[4].strip("\"")
            city = split[2].strip("\"")
            country = split[3].strip("\"")
            x = float(split[6])
            y = float(split[7])
            if city and country and x and y:
                codes.add(code)
    return codes


def distance(fr, to):
    """
    calculates the distance between the two airports fr and to
    e.g. http://www.koordinaten.de/informationen/formel.shtml
    :rtype: float
    :return the distance between fr and to
    """
    if fr == to:
        return 0.0
    try:
        return math.acos(
            math.sin(math.radians(fr.x)) * math.sin(math.radians(to.x)) +
            math.cos(math.radians(fr.x)) * math.cos(math.radians(to.x)) *
            math.cos(math.radians(to.y - fr.y))
        ) * 6378.137
    except ArithmeticError:
        print(fr.code + " " + to.code)
        sys.exit()


def print_path(airport_path):
    """
    prints a traveled path (airports) and calculates the distance
    :param airport_path: the path of airports
    """
    for a in airport_path:
        print(a)
    dist = 0.0
    for i in range(len(airport_path) - 1):
        dist += distance(airport_path[i], airport_path[i + 1])
    print("distance: %d km" % dist)


def suggest_next(fr):
    """
    random next airport based on the given airports connections
    :param fr: the airport
    :return: random next airport connected to the given one
    """
    fr_connections = list(fr.connections)
    return fr_connections[random.randint(0, len(fr_connections) - 1)]


def construct_path(parent, fr, to):
    """
    constructs the search path as list based on the parent relations during the search
    :rtype: list
    :return the path
    """
    path = [to]
    while path[-1] != fr:  # last element of path is not fr
        path.append(parent[path[-1]])
    path.reverse()  # path is in wrong order, so reverse
    return path


class Airport:
    """
    implements an airport with airport code, city, country, x, y, and connections
    """

    def __str__(self) -> str:
        return "%s, %s, %s" % (self.code, self.city, self.country)

    def __init__(self, code):
        """
        creates an airport object with the given code
        :param code: code of the airport
        """
        self.code = code
        self.connections = []
        self.city = ""
        self.country = ""
        self.x = 0.0
        self.y = 0.0

    def set(self, city, country, x, y):
        """
        sets the required information for this airport
        :param city: the city name
        :param country: the country name
        :param x: coordinate x longitude
        :param y: coordinate y latitude
        """
        self.city = city
        self.country = country
        self.x = x
        self.y = y

    def fly_to(self, to):
        """
        adds a connection for this airport
        :param to: the airport to which a connection exists
        """
        if to not in self.connections:
            self.connections.append(to)


class Airports:
    """
    implements a set of airports with their connections
    """

    def __init__(self):
        """
        creates the collection of airports by reading all data files
        """
        self.airports_by_codes = {}  # a dictionary with code as key and airport as value
        self.airports_by_cities = {}  # a dictionary with city as key and a set of its airports as value
        self.airports_by_countries = {}  # a dictionary with countries as key and a set of its airports as values

        # identify all good codes (contain all information and have at least one route) as first filter
        self.good_codes = codes_with_routes(codes_with_airport_info())

        # get remaining information for airports
        self.read_routes()
        self.read_airport_info()
        self.index_cities()
        self.index_countries()

    def get(self, code):
        """
        gets a single airport based on its code
        :param code: the code of the airport
        :return: the airport if already available, if not a new airport
        """
        if code not in self.airports_by_codes:
            a = Airport(code)
            self.airports_by_codes[code] = a
        return self.airports_by_codes[code]

    def read_routes(self):
        """
        reads the routes of airports from the routes.dat file
        """
        for line in open("routes.dat", encoding='utf-8'):
            split = line.split(",")
            fr = split[2].strip("\"")
            to = split[4].strip("\"")
            if fr in self.good_codes and to in self.good_codes:
                fr_airport = self.get(fr)
                to_airport = self.get(to)
                fr_airport.fly_to(to_airport)
                to_airport.fly_to(fr_airport)

    def read_airport_info(self):
        """
        reads the information of all airports from the airports.dat file
        """
        for line in open("airports.dat", encoding='utf-8'):
            split = line.split(",")
            if len(split) == 12:
                code = split[4].strip("\"")
                city = split[2].strip("\"")
                country = split[3].strip("\"")
                x = float(split[6])
                y = float(split[7])
                if code in self.airports_by_codes and code in self.good_codes:
                    self.airports_by_codes[code].set(city, country, x, y)

    def index_cities(self):
        """
        indexes all cities and fills the dictionary of cities and airports
        """
        for code in self.good_codes:
            city = self.airports_by_codes[code].city
            self.airports_by_cities[city] = self.airports_by_cities.get(city, set([]))
            self.airports_by_cities[city].add(code)

    def index_countries(self):
        """
        indexes all countries and fills the dictionary of countries and airports
        """
        for code in self.good_codes:
            c = self.airports_by_codes[code].country
            self.airports_by_countries[c] = self.airports_by_countries.get(c, set([]))
            self.airports_by_countries[c].add(code)

    def suggest_airport(self, string):
        """
        suggest a next airport based on the given string
        :param string: airport code, city name, country, or empty
        :return: airport associated to code, random airport in city or country, otherwise random airport
        """
        # string is an airport code
        if string in self.airports_by_codes:
            return self.airports_by_codes[string]
        # string is a city, then return random airport code for that city
        elif string in self.airports_by_cities:
            airports_in_city = list(self.airports_by_cities[string])
            return self.airports_by_codes[airports_in_city[random.randint(0, len(airports_in_city) - 1)]]
        # string is a country, then return random airport code for that country
        elif string in self.airports_by_countries:
            airports_in_country = list(self.airports_by_countries[string])
            return self.airports_by_codes[airports_in_country[random.randint(0, len(airports_in_country) - 1)]]
        # return random airport code
        else:
            airport_codes = list(self.airports_by_codes.keys())
            return self.airports_by_codes[airport_codes[random.randint(0, len(airport_codes) - 1)]]

# %%
def bfs(fr, to):
    """
    implementation of breadth-first search from airport fr to airport to
    :param fr: the starting airport
    :param to: the destination airport
    :return: the found path
    """
    # FIFO queue of nodes to be processed
    queue = [fr]
    # Avoid loops by keeping track of visited nodes
    visited = {}
    # Store parent of node to get path from fr to to
    parent = {}
    while queue:
        n = queue.pop(0)  # get first node of queue
        visited[n] = True
        if n == to:  # solution found
            print("visited nodes: " + str(len(visited)))
            return construct_path(parent, fr, to)
        for nn in n.connections:  # add successors to queue
            if nn not in visited and nn not in queue:
                parent[nn] = n
                queue.append(nn)  # add nn to the end (important!) of queue (FIFO)

# %%
def dfs(fr, to):
    visited = []
    stack = [fr]
    parents = {}
    while stack:
        n = stack.pop(-1)
        visited.append(n)
        if n == to:
            print("visited nodes: " + str(len(visited)))
            return construct_path(parents, fr, to)
        for nn in n.connections:
            if nn not in stack and nn not in visited:
                parents[nn] = n
                stack.append(nn)

# %%
def components(airports_by_codes):
    """
    finds connected components in the given network by doing breadth-first search
    :param airports_by_codes: dictionary of all airports, codes as keys, airports as values
    :return: dictionary of all airports, component as key, airports as values
    """
    nodes = list(airports_by_codes.values())
    visited = {}
    component = {}
    # create dictionary for components and visited airports
    for v in nodes:
        visited[v] = False
        component[v] = 0
    component_number = 1
    # breadth-first search for each component
    while nodes:
        leaves = list([nodes[0]])
        while leaves:
            n = leaves.pop()
            nodes.remove(n)
            visited[n] = True
            component[n] = component_number
            for nn in n.connections:
                if visited[nn] is False and nn not in leaves:
                    leaves.append(nn)
        component_number += 1
    # grouping airports by their components
    airports_by_components = {}
    for a in airports_by_codes.values():
        component_number = component.get(a)
        if component_number not in airports_by_components:
            airports_by_components[component_number] = [a]
        else:
            airports_by_components[component_number].append(a)
    return airports_by_components

# %%
airports = Airports()

allComponents =  components(airports.airports_by_codes)
for v in allComponents.values():
    for i in v:
        print(i)
    print()
# Out:
# AER, Sochi, Russia
# KZN, Kazan, Russia
# ASF, Astrakhan, Russia
# MRV, Mineralnye Vody, Russia
# CEK, Chelyabinsk, Russia
# OVB, Novosibirsk, Russia
# DME, Moscow, Russia
# NBC, Nizhnekamsk, Russia
# UUA, Bugulma, Russia
# EGO, Belgorod, Russia
# KGD, Kaliningrad, Russia
# GYD, Baku, Azerbaijan
# LED, St. Petersburg, Russia
# SVX, Yekaterinburg, Russia
# NJC, Nizhnevartovsk, Russia
# NUX, Novy Urengoy, Russia
# BTK, Bratsk, Russia
# IKT, Irkutsk, Russia
# HTA, Chita, Russia
# ODO, Bodaibo, Russia
# UKX, Ust-Kut, Russia
# ULK, Lensk, Russia
# YKS, Yakutsk, Russia
# MJZ, Mirnyj, Russia
# AYP, Ayacucho, Peru
# LIM, Lima, Peru
# CUZ, Cuzco, Peru
# PEM, Puerto Maldonado, Peru
# HUU, Huánuco, Peru
# IQT, Iquitos, Peru
# PCL, Pucallpa, Peru
# TPP, Tarapoto, Peru
# ABJ, Abidjan, Cote d'Ivoire
# BOY, Bobo-dioulasso, Burkina Faso
# OUA, Ouagadougou, Burkina Faso
# ACC, Accra, Ghana
# BKO, Bamako, Mali
# DKR, Dakar, Senegal
# COO, Cotonou, Benin
# LFW, Lome, Togo
# NIM, Niamey, Niger
# BOG, Bogota, Colombia
# GYE, Guayaquil, Ecuador
# UIO, Quito, Ecuador
# CLO, Cali, Colombia
# SCY, San Cristóbal, Ecuador
# OCC, Coca, Ecuador
# BDS, Brindisi, Italy
# ZRH, Zurich, Switzerland
# BOD, Bordeaux, France
# BRS, Bristol, United Kingdom
# GVA, Geneva, Switzerland
# LPA, Gran Canaria, Spain
# LCA, Larnaca, Cyprus
# RMF, Marsa Alam, Egypt
# TFS, Tenerife, Spain
# AJR, Arvidsjaur, Sweden
# LYC, Lycksele, Sweden
# ARN, Stockholm, Sweden
# GEV, Gallivare, Sweden
# HAD, Halmstad, Sweden
# JKG, Joenkoeping, Sweden
# KRF, Kramfors, Sweden
# KSD, Karlstad, Sweden
# MHQ, Mariehamn, Finland
# OER, Ornskoldsvik, Sweden
# POR, Pori, Finland
# TRF, Sandefjord, Norway
# VBY, Visby, Sweden
# VHM, Vilhelmina, Sweden
# VXO, Vaxjo, Sweden
# HMV, Hemavan, Sweden
# KOK, Kruunupyy, Finland
# TKU, Turku, Finland
# OSL, Oslo, Norway
# ADQ, Kodiak, United States
# AOS, Amook Bay, United States
# KKB, Kitoi Bay, United States
# KLN, Larsen Bay, United States
# KOZ, Ouzinkie, United States
# OLH, Old Harbor, United States
# KZB, Zachar Bay, United States
# SYB, Seal Bay, United States
# KYK, Karluk, United States
# ORI, Port Lions, United States
# KPR, Port Williams, United States
# BSO, Basco, Philippines
# MNL, Manila, Philippines
# BXU, Butuan, Philippines
# CBO, Cotabato, Philippines
# CGY, Ladag, Philippines
# CRM, Catarman, Philippines
# DGT, Dumaguete, Philippines
# DWC, Dubai, United Arab Emirates
# GES, General Santos City, Philippines
# KLO, Kalibo, Philippines
# LGP, Legazpi, Philippines
# MPH, Caticlan, Philippines
# OZC, Ozamis, Philippines
# PPS, Puerto Princesa, Philippines
# RXS, Roxas City, Philippines
# SUG, Sangley Point, Philippines
# TUG, Tuguegarao, Philippines
# ZAM, Zamboanga, Philippines
# AUX, Araguaina, Brazil
# PMW, Palmas, Brazil
# BRA, Barreiras, Brazil
# BSB, Brasilia, Brazil
# SSA, Salvador, Brazil
# OPS, Sinop, Brazil
# RAO, Ribeirao Preto, Brazil
# CAC, Cascavel, Brazil
# GRU, Sao Paulo, Brazil
# CGB, Cuiaba, Brazil
# GYN, Goiania, Brazil
# CGR, Campo Grande, Brazil
# DOU, Dourados, Brazil
# GIG, Rio De Janeiro, Brazil
# UBA, Uberaba, Brazil
# UDI, Uberlandia, Brazil
# VDC, Vitória Da Conquista, Brazil
# PLU, Belo Horizonte, Brazil
# SJP, Sao Jose Do Rio Preto, Brazil
# BRL, Burlington, United States
# ORD, Chicago, United States
# STL, St. Louis, United States
# DEC, Decatur, United States
# JBR, Jonesboro, United States
# CGA, Craig, United States
# HYL, Hollis, United States
# KTN, Ketchikan, United States
# KTB, Thorne Bay, United States
# MTM, Metakatla, United States
# LOS, Lagos, Nigeria
# ROB, Monrovia, Liberia
# BCN, Barcelona, Spain
# BJL, Banjul, Gambia
# FNA, Freetown, Sierra Leone
# CKY, Conakry, Guinea
# OXB, Bissau, Guinea-Bissau
# DLA, Douala, Cameroon
# LGW, London, United Kingdom
# AKV, Akulivik, Canada
# YIK, Ivujivik, Canada
# YPX, Puvirnituq, Canada
# XGR, Kangiqsualujjuaq, Canada
# YVP, Quujjuaq, Canada
# YGL, La Grande Riviere, Canada
# YGW, Kuujjuarapik, Canada
# YUL, Montreal, Canada
# YPH, Inukjuak, Canada
# YSK, Sanikiluaq, Canada
# YUD, Umiujaq, Canada
# YUY, Rouyn, Canada
# YZG, Salluit, Canada
# YKG, Kangirsuk, Canada
# YPJ, Aupaluk, Canada
# YQC, Quaqtaq, Canada
# YKL, Schefferville, Canada
# YQB, Quebec, Canada
# YWK, Wabush, Canada
# YZV, Sept-iles, Canada
# YTQ, Tasiujaq, Canada
# YWB, Kangiqsujuaq, Canada
# JIB, Djibouti, Djibouti
# DXB, Dubai, United Arab Emirates
# JED, Jeddah, Saudi Arabia
# MGQ, Mogadishu, Somalia
# NBO, Nairobi, Kenya
# BKK, Bangkok, Thailand
# SIN, Singapore, Singapore
# DRW, Darwin, Australia
# HAK, Haikou, China
# HGH, Hangzhou, China
# HKG, Hong Kong, Hong Kong
# HKT, Phuket, Thailand
# KIX, Osaka, Japan
# TPE, Taipei, Taiwan
# KUL, Kuala Lumpur, Malaysia
# PEN, Penang, Malaysia
# PER, Perth, Australia
# PNH, Phnom-penh, Cambodia
# REP, Siem-reap, Cambodia
# RGN, Yangon, Burma
# SGN, Ho Chi Minh City, Vietnam
# SWA, Shantou, China
# ACH, Altenrhein, Switzerland
# EBA, Marina Di Campo, Italy
# DRS, Dresden, Germany
# DUS, Duesseldorf, Germany
# FDH, Friedrichshafen, Germany
# MUC, Munich, Germany
# HAM, Hamburg, Germany
# OLB, Olbia, Italy
# TXL, Berlin, Germany
# ZAD, Zadar, Croatia
# FMM, Memmingen, Germany
# NAP, Naples, Italy
# GRZ, Graz, Austria
# SZG, Salzburg, Austria
# ATL, Atlanta, United States
# LWB, Lewisburg, United States
# MCN, Macon, United States
# MEI, Meridian, United States
# MSL, Muscle Shoals, United States
# PIB, Hattiesburg/Laurel, United States
# TUP, Tupelo, United States
# BIM, Alice Town, Bahamas
# FLL, Fort Lauderdale, United States
# ELH, North Eleuthera, Bahamas
# PBI, West Palm Beach, United States
# EYW, Key West, United States
# RSW, Fort Myers, United States
# TPA, Tampa, United States
# FPO, Freeport, Bahamas
# GGT, Great Exuma, Bahamas
# GHB, Governor's Harbor, Bahamas
# MCO, Orlando, United States
# MHH, Marsh Harbor, Bahamas
# TCB, Treasure Cay, Bahamas
# GLH, Greenville, United States
# GNV, Gainesville, United States
# JAX, Jacksonville, United States
# PNS, Pensacola, United States
# TLH, Tallahassee, United States
# AMS, Amsterdam, Netherlands
# NDR, El Aroui, Morocco
# TNG, Tanger, Morocco
# CMN, Casablanca, Morocco
# BGY, Bergamo, Italy
# BLQ, Bologna, Italy
# BRU, Brussels, Belgium
# CGN, Cologne, Germany
# CUF, Cuneo, Italy
# LYS, Lyon, France
# MPL, Montpellier, France
# SAW, Istanbul, Turkey
# TLS, Toulouse, France
# TSF, Treviso, Italy
# FEZ, Fes, Morocco
# PMI, Palma de Mallorca, Spain
# AUA, Oranjestad, Aruba
# LSP, Paraguana, Venezuela
# MAR, Maracaibo, Venezuela
# BON, Kralendijk, Netherlands Antilles
# CUR, Willemstad, Netherlands Antilles
# BHK, Bukhara, Uzbekistan
# FEG, Fergana, Uzbekistan
# KSQ, Khanabad, Uzbekistan
# NMA, Namangan, Uzbekistan
# NVI, Navoi, Uzbekistan
# SKD, Samarkand, Uzbekistan
# TIV, Tivat, Montenegro
# ANU, Antigua, Antigua and Barbuda
# PTP, Pointe-a-pitre, Guadeloupe
# CAY, Cayenne, French Guiana
# FDF, Fort-de-france, Martinique
# SDQ, Santo Domingo, Dominican Republic
# DOM, Dominica, Dominica
# SXM, Philipsburg, Netherlands Antilles
# SLU, Castries, Saint Lucia
# SBH, Gustavia, France
# SFG, St. Martin, Guadeloupe
# BHY, Beihai, China
# XIY, Xi'an, China
# CAN, Guangzhou, China
# CKG, Chongqing, China
# CTU, Chengdu, China
# SPN, Saipan, Northern Mariana Islands
# CGO, Zhengzhou, China
# CGQ, Changchun, China
# HRB, Harbin, China
# KMG, Kunming, China
# URC, Urumqi, China
# NKG, Nanjing, China
# TNA, Jinan, China
# TSN, Tianjin, China
# CSX, Changcha, China
# CZX, Changzhou, China
# DLC, Dalian, China
# DYG, Dayong, China
# INC, Yinchuan, China
# KHN, Nanchang, China
# LHW, Lanzhou, China
# LJG, Lijiang, China
# LXA, Lhasa, China
# NGB, Ninbo, China
# NNG, Nanning, China
# PEK, Beijing, China
# PVG, Shanghai, China
# PZI, Panzhihua, China
# SYD, Sydney, Australia
# SYX, Sanya, China
# SZX, Shenzhen, China
# TSA, Taipei, Taiwan
# TYN, Taiyuan, China
# WUH, Wuhan, China
# WUX, Wuxi, China
# XNN, Xining, China
# YIH, Yichang, China
# ZHA, Zhanjiang, China
# FOC, Fuzhou, China
# SHE, Shenyang, China
# WNZ, Wenzhou, China
# XMN, Xiamen, China
# DCY, Daocheng, China
# DSN, Dongsheng, China
# HDG, Handan, China
# HET, Hohhot, China
# HFE, Hefei, China
# ICN, Seoul, South Korea
# JHG, Jinghong, China
# JIQ, Qianjiang, China
# JZH, Jiuzhaigou, China
# KOW, Ganzhou, China
# KWE, Guiyang, China
# LUM, Luxi, China
# LZY, Nyingchi, China
# MEL, Melbourne, Australia
# SJW, Shijiazhuang, China
# TAO, Qingdao, China
# WXN, Wanxian, China
# XIC, Xichang, China
# XUZ, Xuzhou, China
# YTY, Yangzhou, China
# ZUH, Zhuhai, China
# DAT, Datong, China
# DNH, Dunhuang, China
# GXH, Xiahe city, China
# NZH, Manzhouli, China
# KWL, Guilin, China
# JGN, Jiayuguan, China
# JJN, Quanzhou, China
# KHG, Kashi, China
# MIG, Mianyang, China
# LYI, Linyi, China
# NTG, Nantong, China
# ZHY, Zhongwei, China
# YVR, Vancouver, Canada
# YBP, Yibin, China
# TVS, Tangshan, China
# UYN, Yulin, China
# LAS, Las Vegas, United States
# LAX, Los Angeles, United States
# CAI, Cairo, Egypt
# TLV, Tel-aviv, Israel
# MCG, Mcgrath, United States
# NIB, Nikolai, United States
# TCT, Takotna, United States
# BRE, Bremen, Germany
# BRI, Bari, Italy
# BUD, Budapest, Hungary
# CAG, Cagliari, Italy
# CDG, Paris, France
# CFU, Kerkyra/corfu, Greece
# CLY, Calvi, France
# CTA, Catania, Italy
# DBV, Dubrovnik, Croatia
# DUB, Dublin, Ireland
# EDI, Edinburgh, United Kingdom
# FAO, Faro, Portugal
# FCO, Rome, Italy
# HDF, Heringsdorf, Germany
# HER, Heraklion, Greece
# IBZ, Ibiza, Spain
# JMK, Mykonos, Greece
# JTR, Thira, Greece
# KGS, Kos, Greece
# KLU, Klagenfurt, Austria
# KVA, Kavala, Greece
# LEJ, Leipzig, Germany
# LHR, London, United Kingdom
# LIS, Lisbon, Portugal
# MAN, Manchester, United Kingdom
# MXP, Milano, Italy
# NCE, Nice, France
# PMO, Palermo, Italy
# PRG, Prague, Czech Republic
# PSA, Pisa, Italy
# PUY, Pula, Croatia
# RAK, Marrakech, Morocco
# RHO, Rhodos, Greece
# RJK, Rijeka, Croatia
# RLG, Laage, Germany
# SJJ, Sarajevo, Bosnia and Herzegovina
# SKG, Thessaloniki, Greece
# SPU, Split, Croatia
# STN, London, United Kingdom
# SUF, Lamezia, Italy
# TUN, Tunis, Tunisia
# VCE, Venice, Italy
# VIE, Vienna, Austria
# VRN, Villafranca, Italy
# WAW, Warsaw, Poland
# XRY, Jerez, Spain
# ZAG, Zagreb, Croatia
# CWL, Cardiff, United Kingdom
# DTM, Dortmund, Germany
# KTW, Katowice, Poland
# MAD, Madrid, Spain
# NQY, Newquai, United Kingdom
# NUE, Nuernberg, Germany
# POZ, Poznan, Poland
# TRN, Torino, Italy
# WRO, Wroclaw, Poland
# FKB, Karlsruhe/Baden-Baden, Germany
# FRA, Frankfurt, Germany
# HEL, Helsinki, Finland
# KRK, Krakow, Poland
# LIN, Milan, Italy
# AKP, Anaktuvuk Pass, United States
# FAI, Fairbanks, United States
# BTT, Bettles, United States
# CXF, Coldfoot, United States
# CEM, Central, United States
# IRC, Circle, United States
# CIK, Chalkyitsik, United States
# FYU, Fort Yukon, United States
# MLY, Manley Hot Springs, United States
# RMP, Rampart, United States
# TAL, Tanana, United States
# WBQ, Beaver, United States
# MNT, Minto, United States
# AKI, Akiak, United States
# TLT, Tuluksak, United States
# ATT, Austin TX, United States
# KUK, Kasigluk, United States
# BET, Bethel, United States
# EEK, Eek, United States
# GNU, Goodnews Bay, United States
# KPN, Kipnuk, United States
# KWN, Quinhagak, United States
# KWT, Kwethluk, United States
# MLL, Marshall, United States
# NME, Nightmute, United States
# WTL, Tuntutuliak, United States
# CYF, Chefornak, United States
# PTU, Port Moller, United States
# KKH, Kongiganak, United States
# KWK, Kwigillingok, United States
# NUP, Nunapitchuk, United States
# PQS, Pilot Station, United States
# OOK, Toksook Bay, United States
# TNK, Tununak, United States
# WWT, Newtok, United States
# BOC, Bocas Del Toro, Panama
# DRK, Puntarenas, Costa Rica
# FON, La Fortuna/San Carlos, Costa Rica
# XQP, Quepos, Costa Rica
# GLF, Golfito, Costa Rica
# PJM, Puerto Jimenez, Costa Rica
# LIR, Liberia, Costa Rica
# SYQ, San Jose, Costa Rica
# TNO, Nicoya, Costa Rica
# MGA, Managua, Nicaragua
# NOB, Nosara Beach, Costa Rica
# TMU, Nicoya, Costa Rica
# PMZ, Palmar Sur, Costa Rica
# TTQ, Roxana, Costa Rica
# KMS, Kumasi, Ghana
# EDL, Eldoret, Kenya
# LOK, Lodwar, Kenya
# JUB, Juba, South Sudan
# KIS, Kisumu, Kenya
# LAU, Lamu, Kenya
# MYD, Malindi, Kenya
# MBA, Mombasa, Kenya
# ZNZ, Zanzibar, Tanzania
# BCD, Bacolod, Philippines
# CEB, Cebu, Philippines
# DVO, Davao, Philippines
# BKI, Kota Kinabalu, Malaysia
# BWN, Bandar Seri Begawan, Brunei
# CGM, Camiguin, Philippines
# CRK, Angeles City, Philippines
# DPL, Dipolog, Philippines
# ILO, Iloilo, Philippines
# PAG, Pagadian, Philippines
# PUS, Busan, South Korea
# TAC, Tacloban, Philippines
# USU, Busuanga, Philippines
# CGK, Jakarta, Indonesia
# MFM, Macau, Macau
# CYZ, Cauayan, Philippines
# DPS, Denpasar, Indonesia
# HAN, Hanoi, Vietnam
# LAO, Laoag, Philippines
# NGO, Nagoya, Japan
# NRT, Tokyo, Japan
# SJI, San Jose, Philippines
# TAG, Tagbilaran, Philippines
# VRC, Virac, Philippines
# WNP, Naga, Philippines
# NEV, Charlestown, Saint Kitts and Nevis
# ARH, Arkhangelsk, Russia
# CSH, Solovetsky Islands, Russia
# MMK, Murmansk, Russia
# NNM, Naryan-Mar, Russia
# SVO, Moscow, Russia
# USK, Usinsk, Russia
# SCW, Syktyvkar, Russia
# TOS, Tromso, Norway
# ANF, Antofagasta, Chile
# IQQ, Iquique, Chile
# CCP, Concepcion, Chile
# SCL, Santiago, Chile
# AEP, Buenos Aires, Argentina
# MVD, Montevideo, Uruguay
# PDP, Punta del Este, Uruguay
# ASU, Asuncion, Paraguay
# CWB, Curitiba, Brazil
# POA, Porto Alegre, Brazil
# YBK, Baker Lake, Canada
# YCS, Chesterfield Inlet, Canada
# YXN, Whale Cove, Canada
# YCB, Cambridge Bay, Canada
# YCO, Coppermine, Canada
# YYH, Spence Bay, Canada
# YRT, Rankin Inlet, Canada
# YCY, Clyde River, Canada
# YFB, Iqaluit, Canada
# YIO, Pond Inlet, Canada
# YEK, Eskimo Point, Canada
# YYQ, Churchill, Canada
# YEV, Inuvik, Canada
# YVQ, Norman Wells, Canada
# YGT, Igloolik, Canada
# YTE, Cape Dorset, Canada
# YUX, Hall Beach, Canada
# YXP, Pangnirtung, Canada
# YHK, Gjoa Haven, Canada
# YUT, Repulse Bay, Canada
# YZS, Coral Harbour, Canada
# YTH, Thompson, Canada
# YVM, Broughton Island, Canada
# YWG, Winnipeg, Canada
# BZE, Belize City, Belize
# FRS, Flores, Guatemala
# SAP, San Pedro Sula, Honduras
# TGU, Tegucigalpa, Honduras
# RTB, Roatan, Honduras
# SLQ, Sleetmute, United States
# ELI, Elim, United States
# KKA, Koyuk, United States
# OME, Nome, United States
# KOT, Kotlik, United States
# GAL, Galena, United States
# RBY, Ruby, United States
# HSL, Huslia, United States
# KAL, Kaltag, United States
# NUL, Nulato, United States
# GAM, Gambell, United States
# SVA, Savoonga, United States
# GLV, Golovin, United States
# WMO, White Mountain, United States
# SCM, Scammon Bay, United States
# KYU, Koyukuk, United States
# IAN, Kiana, United States
# ORV, Noorvik, United States
# SKK, Shaktoolik, United States
# WBB, Stebbins, United States
# MOU, Mountain Village, United States
# KTS, Brevig Mission, United States
# TLA, Teller, United States
# WAA, Wales, United States
# KVL, Kivalina, United States
# TOG, Togiak Village, United States
# MYU, Mekoryuk, United States
# OBU, Kobuk, United States
# SHH, Shishmaref, United States
# PHO, Point Hope, United States
# WLK, Selawik, United States
# WTK, Noatak, United States
# SRV, Stony River, United States
# SMK, St. Michael, United States
# CCS, Caracas, Venezuela
# LRM, La Romana, Dominican Republic
# VLN, Valencia, Venezuela
# BRM, Barquisimeto, Venezuela
# CLT, Charlotte, United States
# KIN, Kingston, Jamaica
# MDE, Rio Negro, Colombia
# PBM, Zandery, Suriname
# POS, Port-of-spain, Trinidad and Tobago
# PAP, Port-au-prince, Haiti
# DYU, Dushanbe, Tajikistan
# ALA, Alma-ata, Kazakhstan
# LBD, Khudzhand, Tajikistan
# FRU, Bishkek, Kyrgyzstan
# IKA, Tehran, Iran
# IST, Istanbul, Turkey
# SGC, Surgut, Russia
# SHJ, Sharjah, United Arab Emirates
# ACU, Achutupo, Panama
# PAC, Panama, Panama
# BFQ, Bahia Piña, Panama
# JQE, Jaqué, Panama
# CHX, Changuinola, Panama
# DAV, David, Panama
# GHE, Garachine, Panama
# MPP, Mulatupo, Panama
# OTD, Contadora Island, Panama
# SIC, Sinop, Turkey
# PUE, Puerto Obaldia, Panama
# PVE, El Porvenir, Panama
# PYC, Playon Chico, Panama
# SAX, Boca de Sábalo, Panama
# AKX, Aktyubinsk, Kazakhstan
# CSY, Cheboksary, Russia
# ESL, Elista, Russia
# GRV, Grozny, Russia
# IJK, Izhevsk, Russia
# MCX, Makhachkala, Russia
# PES, Petrozavodsk, Russia
# PEZ, Penza, Russia
# SKX, Saransk, Russia
# ULV, Ulyanovsk, Russia
# VKT, Vorkuta, Russia
# VOZ, Voronezh, Russia
# KUF, Samara, Russia
# ROV, Rostov, Russia
# VOG, Volgograd, Russia
# IAR, Yaroslavl, Russia
# KRO, Kurgan, Russia
# KVX, Kirov, Russia
# MQF, Magnetiogorsk, Russia
# URJ, Uraj, Russia
# CNX, Chiang Mai, Thailand
# AKK, Akhiok, United States
# LUR, Cape Lisburne, United States
# TNC, Tin City, United States
# BAV, Baotou, China
# TCZ, Tengchong, China
# DIG, Shangri-La, China
# DLU, Dali, China
# SYM, Simao, China
# YIC, Yichun, China
# SHA, Shanghai, China
# QBC, Bella Coola, Canada
# YAA, Anahim Lake, Canada
# YBL, Campbell River, Canada
# YQQ, Comox, Canada
# ZEL, Bella Bella, Canada
# YXC, Cranbrook, Canada
# YPW, Powell River, Canada
# YWL, Williams Lake, Canada
# YYJ, Victoria, Canada
# YZT, Port Hardy, Canada
# YZZ, Trail, Canada
# ZMT, Masset, Canada
# ADA, Adana, Turkey
# ADB, Izmir, Turkey
# BJV, Bodrum, Turkey
# DIY, Diyabakir, Turkey
# DLM, Dalaman, Turkey
# ECN, Nicosia, Cyprus
# ERZ, Erzurum, Turkey
# EZS, Elazig, Turkey
# GNY, Sanliurfa, Turkey
# GZP, Alanya, Turkey
# GZT, Gaziantep, Turkey
# MLX, Malatya, Turkey
# ODS, Odessa, Ukraine
# TZX, Trabzon, Turkey
# MDQ, Mar Del Plata, Argentina
# PRA, Parana, Argentina
# ROS, Rosario, Argentina
# SFN, Santa Fe, Argentina
# BHI, Bahia Blanca, Argentina
# REL, Trelew, Argentina
# BRC, San Carlos De Bariloche, Argentina
# CRD, Comodoro Rivadavia, Argentina
# EQS, Esquel, Argentina
# COR, Cordoba, Argentina
# MDZ, Mendoza, Argentina
# NQN, Neuquen, Argentina
# RGL, Rio Gallegos, Argentina
# RGA, Rio Grande, Argentina
# USH, Ushuaia, Argentina
# YLE, Whatì, Canada
# YRA, Gamètì, Canada
# YSG, Lutselk'e, Canada
# AKF, Kufra, Libya
# BEN, Benghazi, Libya
# AMM, Amman, Jordan
# TIP, Tripoli, Libya
# MRA, Misratah, Libya
# HBE, Alexandria, Egypt
# SFA, Sfax, Tunisia
# TOB, Tobruk, Libya
# AET, Allakaket, United States
# HUS, Hughes, United States
# ARC, Arctic Village, United States
# VEE, Venetie, United States
# KBC, Brich Creek, United States
# CGD, Changde, China
# LYA, Luoyang, China
# HIA, Huai An, China
# HSG, Saga, Japan
# IBR, Ibaraki, Japan
# KHH, Kaohsiung, Taiwan
# TAK, Takamatsu, Japan
# NDJ, N'djamena, Chad
# AZO, Kalamazoo, United States
# CHA, Chattanooga, United States
# CID, Cedar Rapids, United States
# CRW, Charleston, United States
# CVG, Cincinnati, United States
# EVV, Evansville, United States
# FWA, Fort Wayne, United States
# GSO, Greensboro, United States
# GSP, Greenville, United States
# LAN, Lansing, United States
# LEX, Lexington KY, United States
# MBS, Saginaw, United States
# MSP, Minneapolis, United States
# ROA, Roanoke VA, United States
# SYR, Syracuse, United States
# TYS, Knoxville, United States
# XNA, Bentonville, United States
# DTW, Detroit, United States
# MSY, New Orleans, United States
# GFK, Grand Forks, United States
# TVF, Thief River Falls, United States
# LGA, New York, United States
# MDT, Harrisburg, United States
# MEM, Memphis, United States
# ACK, Nantucket, United States
# BOS, Boston, United States
# EWB, New Bedford, United States
# HYA, Barnstable, United States
# MVY, Vineyard Haven MA, United States
# ALB, Albany, United States
# MSS, Massena, United States
# OGS, Ogdensburg, United States
# AUG, Augusta, United States
# AXA, The Valley, Anguilla
# SJU, San Juan, Puerto Rico
# BHB, Bar Harbor, United States
# BIL, Billings, United States
# GDV, Glendive, United States
# GGW, Glasgow, United States
# HVR, Havre, United States
# OLF, Wolf Point, United States
# SDY, Sidney, United States
# LEB, Lebanon, United States
# PVC, Provincetown, United States
# RKD, Rockland, United States
# RUT, Rutland, United States
# SLK, Saranac Lake, United States
# CGI, Cape Girardeau, United States
# CPX, Culebra Island, Puerto Rico
# EIS, Tortola, British Virgin Islands
# STT, St. Thomas, Virgin Islands
# HPN, White Plains, United States
# IRK, Kirksville, United States
# MAZ, Mayaguez, Puerto Rico
# MWA, Marion, United States
# OWB, Owensboro, United States
# STX, St. Croix Island, Virgin Islands
# VIJ, Spanish Town, British Virgin Islands
# VQS, Vieques Island, Puerto Rico
# TBN, Fort Leonardwood, United States
# UIN, Quincy, United States
# YDQ, Dawson Creek, Canada
# YYE, Fort Nelson, Canada
# YOJ, High Level, Canada
# YOP, Rainbow Lake, Canada
# YXJ, Fort Saint John, Canada
# YKA, Kamloops, Canada
# YXS, Prince George, Canada
# YLL, Lloydminster, Canada
# YQZ, Quesnel, Canada
# YXT, Terrace, Canada
# YYD, Smithers, Canada
# BCV, Belmopan, Belize
# CUK, Caye Caulker, Belize
# SPR, San Pedro, Belize
# TZA, Belize, Belize
# DGA, Dangriga, Belize
# PLJ, Placencia, Belize
# CZH, Corozal, Belize
# PND, Punta Gorda, Belize
# GDT, Cockburn Town, Turks and Caicos Islands
# PLS, Providenciales, Turks and Caicos Islands
# SLX, Salt Cay, Turks and Caicos Islands
# ACR, Araracuara, Colombia
# LCR, La Chorrera, Colombia
# SVI, San Vincente De Caguan, Colombia
# ADZ, San Andres Island, Colombia
# PVA, Providencia, Colombia
# APO, Apartadó, Colombia
# EOH, Medellin, Colombia
# AUC, Arauca, Colombia
# BUN, Buenaventura, Colombia
# CZU, Corozal, Colombia
# FLA, Florencia, Colombia
# IPI, Ipiales, Colombia
# MVP, Mitu, Colombia
# PCR, Puerto Carreno, Colombia
# PDA, Puerto Inírida, Colombia
# PSO, Pasto, Colombia
# PUU, Puerto Asis, Colombia
# RVE, Saravena, Colombia
# SJE, San Jose Del Guaviare, Colombia
# TME, Tame, Colombia
# UIB, Quibdo, Colombia
# VGZ, Villa Garzon, Colombia
# VVC, Villavicencio, Colombia
# BSC, Bahia Solano, Colombia
# GPI, Guapi, Colombia
# NQU, Nuquí, Colombia
# LET, Leticia, Colombia
# LPD, La Pedrera, Colombia
# TCD, Tarapacá, Colombia
# LMC, La Macarena, Colombia
# LQM, Puerto Leguízamo, Colombia
# KIV, Chisinau, Moldova
# BVA, Beauvais, France
# KBP, Kiev, Ukraine
# OTP, Bucharest, Romania
# BLA, Barcelona, Venezuela
# PMV, Porlamar, Venezuela
# PTY, Panama City, Panama
# PZO, Guayana, Venezuela
# BNS, Barinas, Venezuela
# MRD, Merida, Venezuela
# VLV, Valera, Venezuela
# AJL, Aizwal, India
# AUH, Abu Dhabi, United Arab Emirates
# ATQ, Amritsar, India
# CCJ, Calicut, India
# DMM, Dammam, Saudi Arabia
# KWI, Kuwait, Kuwait
# BAH, Bahrain, Bahrain
# BHJ, Bhuj, India
# BHO, Bhopal, India
# BHU, Bhaunagar, India
# IXE, Mangalore, India
# CMB, Colombo, Sri Lanka
# DIU, Diu, India
# DOH, Doha, Qatar
# IXU, Aurangabad, India
# JDH, Jodhpur, India
# RAJ, Rajkot, India
# RUH, Riyadh, Saudi Arabia
# UDR, Udaipur, India
# EWR, Newark, United States
# YYZ, Toronto, Canada
# IXS, Silchar, India
# IXZ, Port Blair, India
# DED, Dehra Dun, India
# GOP, Gorakhpur, India
# IXL, Leh, India
# PBD, Porbandar, India
# RJA, Rajahmundry, India
# IXM, Madurai, India
# TRZ, Tiruchirappalli, India
# JSH, Sitia, Greece
# JKH, Chios, Greece
# KLX, Kalamata, Greece
# SMI, Samos, Greece
# AOK, Karpathos, Greece
# KSJ, Kasos, Greece
# AXD, Alexandroupolis, Greece
# CHQ, Chania, Greece
# EFL, Keffallinia, Greece
# IEV, Kiev, Ukraine
# IOA, Ioannina, Greece
# JIK, Ikaria, Greece
# JKL, Kalymnos, Greece
# JNX, Cyclades Islands, Greece
# JSI, Skiathos, Greece
# JSY, Syros Island, Greece
# JTY, Astypalaia, Greece
# KIT, Kithira, Greece
# LRS, Leros, Greece
# LXS, Limnos, Greece
# MJT, Mytilini, Greece
# MLO, Milos, Greece
# MRS, Marseille, France
# NTE, Nantes, France
# PAS, Paros, Greece
# PHL, Philadelphia, United States
# SKU, Skiros, Greece
# SOF, Sofia, Bulgaria
# TIA, Tirana, Albania
# ZTH, Zakynthos, Greece
# OPO, Porto, Portugal
# KZS, Kastelorizo, Greece
# BYC, Yacuiba, Bolivia
# SRZ, Santa Cruz, Bolivia
# TJA, Tarija, Bolivia
# CBB, Cochabamba, Bolivia
# TDD, Trinidad, Bolivia
# CIJ, Cobija, Bolivia
# GYA, Guayaramerín, Bolivia
# LPB, La Paz, Bolivia
# POI, Potosi, Bolivia
# RIB, Riberalta, Bolivia
# AGF, Agen, France
# DCM, Castres, France
# ORY, Paris, France
# AJA, Ajaccio, France
# BVE, Brive, France
# PIS, Poitiers, France
# CFE, Clermont-Ferrand, France
# SXB, Strasbourg, France
# AUR, Aurillac, France
# BES, Brest, France
# LIL, Lille, France
# BIQ, Biarritz-bayonne, France
# CFR, Caen, France
# ETZ, Metz, France
# FLR, Florence, Italy
# FSC, Figari, France
# GOT, Gothenborg, Sweden
# LAI, Lannion, France
# LDE, Tarbes, France
# LRH, La Rochelle, France
# LRT, Lorient, France
# MLH, Mulhouse, France
# PUF, Pau, France
# RNS, Rennes, France
# PGF, Perpignan, France
# RDZ, Rodez, France
# UIP, Quimper, France
# EBB, Entebbe, Uganda
# PAF, Pakuba, Uganda
# BUS, Batumi, Georgia
# KUT, Kutaisi, Georgia
# ABE, Allentown, United States
# ABI, Abilene, United States
# ABQ, Albuquerque, United States
# PHX, Phoenix, United States
# ABZ, Aberdeen, United Kingdom
# ACT, Waco, United States
# ADL, Adelaide, Australia
# BNE, Brisbane, Australia
# ISP, Islip, United States
# YHZ, Halifax, Canada
# DRO, Durango, United States
# ELP, El Paso, United States
# FAR, Fargo, United States
# FAT, Fresno, United States
# FSD, Sioux Falls, United States
# FSM, Fort Smith, United States
# GCK, Garden City, United States
# GGG, Longview, United States
# GJT, Grand Junction, United States
# GRI, Grand Island, United States
# GRK, Killeen, United States
# GRR, Grand Rapids, United States
# HNL, Honolulu, United States
# HOU, Houston, United States
# ICT, Wichita, United States
# JLN, Joplin, United States
# LAW, Lawton, United States
# LBB, Lubbock, United States
# LCH, Lake Charles, United States
# LFT, Lafayette, United States
# LRD, Laredo, United States
# MAF, Midland, United States
# MFE, Mcallen, United States
# MHK, Manhattan, United States
# MLI, Moline, United States
# MLM, Morelia, Mexico
# MLU, Monroe, United States
# MSN, Madison, United States
# OGG, Kahului, United States
# OKC, Oklahoma City, United States
# ONT, Ontario, United States
# PBC, Puebla, Mexico
# PIA, Peoria, United States
# PSP, Palm Springs, United States
# QRO, Queretaro, Mexico
# RAP, Rapid City, United States
# RNO, Reno, United States
# ROW, Roswell, United States
# SAF, Santa Fe, United States
# SAL, San Salvador, El Salvador
# SGF, Springfield, United States
# SHV, Shreveport, United States
# SJC, San Jose, United States
# SJT, San Angelo, United States
# SLP, San Luis Potosi, Mexico
# SPI, Springfield, United States
# SPS, Wichita Falls, United States
# TUL, Tulsa, United States
# TUS, Tucson, United States
# TXK, Texarkana, United States
# TYR, Tyler, United States
# ELM, Elmira, United States
# ERI, Erie, United States
# EUG, Eugene, United States
# FLG, Flagstaff, United States
# FNT, Flint, United States
# GEG, Spokane, United States
# GIB, Gibraltar, Gibraltar
# GLA, Glasgow, United Kingdom
# GND, Point Salines, Grenada
# GRB, Green Bay, United States
# OAK, Oakland, United States
# HVN, New Haven, United States
# IPT, Williamsport, United States
# ITH, Ithaca, United States
# ITM, Osaka, Japan
# LCY, London, United Kingdom
# JNU, Juneau, United States
# JUL, Juliaca, Peru
# KOA, Kona, United States
# LGK, Pulau, Malaysia
# LIH, Lihue, United States
# MFR, Medford, United States
# MMH, Mammoth Lakes, United States
# MRY, Monterey, United States
# NAN, Nandi, Fiji
# RDM, Redmond-Bend, United States
# STS, Santa Rosa, United States
# LBA, Leeds, United Kingdom
# LGB, Long Beach, United States
# LUX, Luxemburg, Luxembourg
# NCL, Newcastle, United Kingdom
# RTM, Rotterdam, Netherlands
# SVG, Stavanger, Norway
# VVI, Santa Cruz, Bolivia
# LSE, La Crosse, United States
# MAO, Manaus, Brazil
# POP, Puerto Plata, Dominican Republic
# REC, Recife, Brazil
# SKB, Basse Terre, Saint Kitts and Nevis
# STI, Santiago, Dominican Republic
# MQT, Marquette, United States
# RST, Rochester, United States
# SUX, Sioux City, United States
# TOL, Toledo, United States
# TVC, Traverse City, United States
# YKF, Waterloo, Canada
# SCE, State College Pennsylvania, United States
# SWF, Newburgh, United States
# SBA, Santa Barbara, United States
# SBP, San Luis Obispo, United States
# YUM, Yuma, United States
# PMC, Puerto Montt, Chile
# LPQ, Luang Prabang, Laos
# BLL, Billund, Denmark
# BZV, Brazzaville, Congo (Brazzaville)
# EXT, Exeter, United Kingdom
# GOA, Genoa, Italy
# LBV, Libreville, Gabon
# LJU, Ljubljana, Slovenia
# MRU, Plaisance, Mauritius
# NKC, Nouakschott, Mauritania
# PNR, Pointe-noire, Congo (Brazzaville)
# RBA, Rabat, Morocco
# TNR, Antananarivo, Madagascar
# VGO, Vigo, Spain
# DAR, Dar Es Salaam, Tanzania
# SSG, Malabo, Equatorial Guinea
# DOL, Deauville, France
# DZA, Dzaoudzi, Mayotte
# HAH, Moroni, Comoros
# EGC, Bergerac, France
# ENH, Enshi, China
# LUN, Lusaka, Zambia
# IVL, Ivalo, Finland
# KTT, Kittila, Finland
# LIG, Limoges, France
# LLW, Lilongwe, Malawi
# LVI, Livingstone, Zambia
# RUN, St.-denis, Reunion
# ZSE, St.-pierre, Reunion
# NBS, Baishan, China
# TLN, Hyeres, France
# ROR, Babelthuap, Palau
# AAE, Annaba, Algeria
# ORN, Oran, Algeria
# AZR, Adrar, Algeria
# BJA, Bejaja, Algeria
# BLJ, Batna, Algeria
# BSK, Biskra, Algeria
# CZL, Constantine, Algeria
# DJG, Djanet, Algeria
# ELU, Guemar, Algeria
# GHA, Ghardaia, Algeria
# HME, Hassi Messaoud, Algeria
# HRM, Tilrempt, Algeria
# INZ, In Salah, Algeria
# MUW, Ghriss, Algeria
# OGX, Ouargla, Algeria
# QSF, Setif, Algeria
# TEE, Tebessa, Algeria
# TGR, Touggourt, Algeria
# TID, Tiaret, Algeria
# TLM, Tlemcen, Algeria
# BMW, Bordj Badji Mokhtar, Algeria
# CBH, Béchar, Algeria
# TMR, Tamanrasset, Algeria
# ELG, El Golea, Algeria
# IAM, Zarzaitine, Algeria
# AGR, Agra, India
# HJR, Khajuraho, India
# AGX, Agatti Island, India
# GWL, Gwalior, India
# IXD, Allahabad, India
# JGA, Jamnagar, India
# DMU, Dimapur, India
# SHL, Shillong, India
# DHM, Kangra, India
# JLR, Jabalpur, India
# KNU, Kanpur, India
# KUU, Kulu, India
# LUH, Ludhiaha, India
# STV, Surat, India
# TIR, Tirupeti, India
# VGA, Vijayawada, India
# MLE, Male, Maldives
# AOR, Alor Setar, Malaysia
# BDO, Bandung, Indonesia
# JHB, Johor Bahru, Malaysia
# KBR, Kota Bahru, Malaysia
# KCH, Kuching, Malaysia
# MYY, Miri, Malaysia
# SDK, Sandakan, Malaysia
# TWU, Tawau, Malaysia
# BPN, Balikpapan, Indonesia
# BTJ, Banda Aceh, Indonesia
# BTU, Bintulu, Malaysia
# DMK, Bangkok, Thailand
# HDY, Hat Yai, Thailand
# SBW, Sibu, Malaysia
# JOG, Yogyakarta, Indonesia
# LBU, Labuan, Malaysia
# LOP, Praya, Indonesia
# PDG, Padang, Indonesia
# PKU, Pekanbaru, Indonesia
# PLM, Palembang, Indonesia
# SOC, Solo City, Indonesia
# SRG, Semarang, Indonesia
# SUB, Surabaya, Indonesia
# TGG, Kuala Terengganu, Malaysia
# UPG, Ujung Pandang, Indonesia
# URT, Surat Thani, Thailand
# VTE, Vientiane, Laos
# CLQ, Colima, Mexico
# CVM, Ciudad Victoria, Mexico
# DGO, Durango, Mexico
# TAP, Tapachula, Mexico
# LMM, Los Mochis, Mexico
# MXL, Mexicali, Mexico
# JAL, Jalapa, Mexico
# LZC, Lazard Cardenas, Mexico
# MAM, Matamoros, Mexico
# NLD, Nuevo Laredo, Mexico
# PAZ, Poza Rico, Mexico
# PDS, Piedras Negras, Mexico
# PXM, Puerto Escondido, Mexico
# SLW, Saltillo, Mexico
# TPQ, Tepic, Mexico
# AFA, San Rafael, Argentina
# CPC, San Martin Des Andes, Argentina
# CTC, Catamarca, Argentina
# FMA, Formosa, Argentina
# FTE, El Calafate, Argentina
# IGR, Iguazu Falls, Argentina
# IRJ, La Rioja, Argentina
# JUJ, Jujuy, Argentina
# LUQ, San Luis, Argentina
# PSS, Posadas, Argentina
# RES, Resistencia, Argentina
# RHD, Rio Hondo, Argentina
# RSA, Santa Rosa, Argentina
# SDE, Santiago Del Estero, Argentina
# SLA, Salta, Argentina
# TUC, Tucuman, Argentina
# UAQ, San Julian, Argentina
# VDM, Viedma, Argentina
# ADK, Adak Island, United States
# AKN, King Salmon, United States
# ALW, Walla Walla, United States
# CDB, Cold Bay, United States
# DLG, Dillingham, United States
# SDP, Sand Point, United States
# SNP, St. Paul Island, United States
# STG, St. George, United States
# BLI, Bellingham, United States
# LWS, Lewiston, United States
# PBG, Plattsburgh, United States
# PQI, Presque Isle, United States
# BZN, Bozeman, United States
# YAK, Yakutat, United States
# EAT, Wenatchee, United States
# FCA, Kalispell, United States
# GTF, Great Falls, United States
# HLN, Helena, United States
# PSG, Petersburg, United States
# SIT, Sitka, United States
# WRG, Wrangell, United States
# LTO, Loreto, Mexico
# PUW, Pullman, United States
# MSO, Missoula, United States
# PSC, Pasco, United States
# YKM, Yakima, United States
# AGA, Agadir, Morocco
# EUN, El Aaiún, Western Sahara
# VIL, Dakhla, Western Sahara
# AHU, Al Hociema, Morocco
# OUD, Oujda, Morocco
# OZZ, Ouarzazate, Morocco
# TFN, Tenerife, Spain
# TTU, Tetouan, Morocco
# ESU, Essadouira, Morocco
# TTA, Tan Tan, Morocco
# AXM, Armenia, Colombia
# BAQ, Barranquilla, Colombia
# BGA, Bucaramanga, Colombia
# CTG, Cartagena, Colombia
# CUC, Cucuta, Colombia
# EJA, Barrancabermeja, Colombia
# EYP, Yopal, Colombia
# IBE, Ibague, Colombia
# MTR, Monteria, Colombia
# MZL, Manizales, Colombia
# NVA, Neiva, Colombia
# PEI, Pereira, Colombia
# PPN, Popayan, Colombia
# RCH, Rio Hacha, Colombia
# SMR, Santa Marta, Colombia
# VUP, Valledupar, Colombia
# TCO, Tumaco, Colombia
# TML, Tamale, Ghana
# BMA, Stockholm, Sweden
# MMX, Malmoe, Sweden
# UME, Umea, Sweden
# JOE, Joensuu, Finland
# JYV, Jyvaskyla, Finland
# KAJ, Kajaani, Finland
# KAO, Kuusamo, Finland
# KEF, Keflavik, Iceland
# KEM, Kemi, Finland
# KUO, Kuopio, Finland
# MSQ, Minsk 2, Belarus
# NRK, Norrkoeping, Sweden
# OUL, Oulu, Finland
# RVN, Rovaniemi, Finland
# SVL, Savonlinna, Finland
# TAY, Tartu, Estonia
# TLL, Tallinn-ulemiste International, Estonia
# TMP, Tampere, Finland
# VAA, Vaasa, Finland
# AAL, Aalborg, Denmark
# PNA, Pamplona, Spain
# AES, Alesund, Norway
# AHO, Alghero, Italy
# HUY, Humberside, United Kingdom
# KRS, Kristiansand, Norway
# MME, Teesside, United Kingdom
# NWI, Norwich, United Kingdom
# KHI, Karachi, Pakistan
# KRT, Khartoum, Sudan
# SEZ, Mahe, Seychelles
# BAY, Baia Mare, Romania
# IAS, Iasi, Romania
# BZO, Bolzano, Italy
# CIY, Comiso, Italy
# CLJ, Cluj-napoca, Romania
# REG, Reggio Calabria, Italy
# TGD, Podgorica, Montenegro
# TRS, Ronchi De Legionari, Italy
# LCG, La Coruna, Spain
# PSR, Pescara, Italy
# OMR, Oradea, Romania
# SUJ, Satu Mare, Romania
# TSR, Timisoara, Romania
# TAS, Tashkent, Uzbekistan
# TGM, Tirgu Mures, Romania
# ASB, Ashkhabad, Turkmenistan
# TSE, Tselinograd, Kazakhstan
# ASV, Amboseli National Park, Kenya
# WIL, Nairobi, Kenya
# HGA, Hargeisa, Somalia
# WJR, Wajir, Kenya
# KTL, Kitale, Kenya
# LKG, Lokichoggio, Kenya
# MRE, Masai Mara, Kenya
# UKA, Ukunda, Kenya
# BQN, Aguadilla, Puerto Rico
# ORH, Worcester, United States
# PSE, Ponce, Puerto Rico
# ABD, Abadan, Iran
# MHD, Mashhad, Iran
# THR, Teheran, Iran
# AWZ, Ahwaz, Iran
# IFN, Isfahan, Iran
# KIH, Kish Island, Iran
# SRY, Dasht-e-naz, Iran
# SYZ, Shiraz, Iran
# AZD, Yazd, Iran
# BND, Bandar Abbas, Iran
# GSM, Gheshm, Iran
# KSH, Bakhtaran, Iran
# RAS, Rasht, Iran
# TBZ, Tabriz, Iran
# ZAH, Zahedan, Iran
# AAR, Aarhus, Denmark
# TAB, Scarborough, Trinidad and Tobago
# DUR, Durban, South Africa
# PLZ, Port Elizabeth, South Africa
# GRX, Granada, Spain
# IOM, Isle Of Man, Isle of Man
# VFA, Victoria Falls, Zimbabwe
# WDH, Windhoek, Namibia
# PFO, Paphos, Cyprus
# SDJ, Sendai, Japan
# UKB, Kobe, Japan
# YGJ, Miho, Japan
# KOJ, Kagoshima, Japan
# ISG, Ishigaki, Japan
# MMY, Miyako, Japan
# NGS, Nagasaki, Japan
# KOI, Kirkwall, United Kingdom
# LSI, Sumburgh, United Kingdom
# EMA, East Midlands, United Kingdom
# INV, Inverness, United Kingdom
# BEB, Benbecula, United Kingdom
# SYY, Stornoway, United Kingdom
# NOC, Connaught, Ireland
# WAT, Waterford, Ireland
# BRR, Barra, United Kingdom
# CAL, Campbeltown, United Kingdom
# CFN, Dongloe, Ireland
# DND, Dundee, United Kingdom
# WIC, Wick, United Kingdom
# ILY, Islay, United Kingdom
# TRE, Tiree, United Kingdom
# LPL, Liverpool, United Kingdom
# GTE, Groote Eylandt, Australia
# MZV, Mulu, Malaysia
# MIR, Monastir, Tunisia
# HJJ, Zhijiang, China
# LLF, Yongzhou, China
# TEN, Tongren, China
# YNT, Yantai, China
# HEK, Heihe, China
# OHE, Mohe County, China
# JGD, Jiagedaqi District, China
# JMU, Jiamusi, China
# JXA, Jixi, China
# BMV, Buonmethuot, Vietnam
# VII, Vinh, Vietnam
# CXR, Nha Trang, Vietnam
# DAD, Danang, Vietnam
# HPH, Haiphong, Vietnam
# PQC, Phu Quoc, Vietnam
# EBJ, Esbjerg, Denmark
# KSU, Kristiansund, Norway
# EVE, Harstad/Narvik, Norway
# BBK, Kasane, Botswana
# GBE, Gaberone, Botswana
# MUB, Maun, Botswana
# FRW, Francistown, Botswana
# AKJ, Asahikawa, Japan
# HKD, Hakodate, Japan
# KMQ, Kanazawa, Japan
# OKJ, Okayama, Japan
# TXN, Huangshan, China
# PLQ, Palanga, Lithuania
# BKY, Bukavu/kavumu, Congo (Kinshasa)
# KND, Kindu, Congo (Kinshasa)
# BUX, Bunia, Congo (Kinshasa)
# GOM, Goma, Congo (Kinshasa)
# IRP, Isiro, Congo (Kinshasa)
# FBM, Lubumashi, Congo (Kinshasa)
# KGA, Kananga, Congo (Kinshasa)
# MJM, Mbuji-mayi, Congo (Kinshasa)
# FKI, Kisangani, Congo (Kinshasa)
# MDK, Mbandaka, Congo (Kinshasa)
# TSH, Tshikapa, Congo (Kinshasa)
# GMA, Gemena, Congo (Kinshasa)
# LJA, Lodja, Congo (Kinshasa)
# CYO, Cayo Largo del Sur, Cuba
# SCU, Santiago De Cuba, Cuba
# GEO, Georgetown, Guyana
# BSG, Bata, Equatorial Guinea
# AKU, Aksu, China
# BPX, Bangda, China
# DAX, Dazhou, China
# GYS, Guangyuan, China
# HYN, Huangyan, China
# JDZ, Jingdezhen, China
# LZO, Luzhou, China
# WUS, Wuyishan, China
# YCU, Yuncheng, China
# CHG, Chaoyang, China
# CIF, Chifeng, China
# CIH, Changzhi, China
# KRL, Korla, China
# YIN, Yining, China
# YIW, Yiwu, China
# DDG, Dandong, China
# HIJ, Hiroshima, Japan
# FNJ, Pyongyang, Korea
# FUG, Fuyang, China
# HLD, Hailar, China
# HLH, Ulanhot, China
# HMI, Hami, China
# HSN, Zhoushan, China
# HTN, Hotan, China
# YNJ, Yanji, China
# JGS, Ji An, China
# JIU, Jiujiang, China
# JNZ, Jinzhou, China
# JUZ, Quzhou, China
# LZH, Liuzhou, China
# MDG, Mudanjiang, China
# MWX, Muan, South Korea
# NDG, Qiqihar, China
# RLK, Bayannur, China
# TAE, Taegu, South Korea
# TGO, Tongliao, China
# ULN, Ulan Bator, Mongolia
# WUA, Wuhai, China
# XFN, Xiangfan, China
# XIL, Xilinhot, China
# PEU, Puerto Lempira, Honduras
# AVN, Avignon, France
# POM, Port Moresby, Papua New Guinea
# BUA, Buka Island, Papua New Guinea
# RAB, Tokua, Papua New Guinea
# DAU, Daru, Papua New Guinea
# LAE, Nadzab, Papua New Guinea
# UNG, Kiunga, Papua New Guinea
# GKA, Goroka, Papua New Guinea
# HGU, Mount Hagen, Papua New Guinea
# MAG, Madang, Papua New Guinea
# GUR, Gurney, Papua New Guinea
# ...
# MTV, Ablow, Vanuatu
# SLH, Sola, Vanuatu
# TOH, Loh/Linua, Vanuatu
# ZGU, Gaua Island, Vanuatu
# MWF, Maewo Island, Vanuatu
# NOU, Noumea, New Caledonia
# SWJ, Malekula Island, Vanuatu
# PBJ, Paama Island, Vanuatu
# SSR, Pentecost Island, Vanuatu
# WLH, Walaha, Vanuatu
# TGH, Tongoa Island, Vanuatu
# VLS, Valesdir, Vanuatu
# SHB, Nakashibetsu, Japan
# WKJ, Wakkanai, Japan
# FUJ, Fukue, Japan
# TSJ, Tsushima, Japan
# HAC, Hachijojima, Japan
# IWJ, Iwami, Japan
# MBE, Monbetsu, Japan
# NTQ, Wajima, Japan
# OIM, Oshima, Japan
# ONJ, Odate Noshiro, Japan
# SYO, Shonai, Japan
# TTJ, Tottori, Japan
# IKI, Iki, Japan
# CFC, Cacador, Brazil
# JCB, Joacaba, Brazil
# GPB, Guarapuava, Brazil
# ERM, Erechim, Brazil
# GEL, Santo Angelo, Brazil
# SRA, Santa Rosa, Brazil
# URG, Uruguaiana, Brazil
# ACY, Atlantic City, United States
# LBE, Latrobe, United States
# SKZ, Sukkur, Pakistan
# GMZ, La Gomera, Spain
# VDE, Hierro, Spain
# UEO, Kumejima, Japan
# AEY, Akureyri, Iceland
# RKV, Reykjavik, Iceland
# EGS, Egilsstadir, Iceland
# IFJ, Isafjordur, Iceland
# BHE, Woodbourne, New Zealand
# GIS, Gisborne, New Zealand
# HLZ, Hamilton, New Zealand
# KAT, Kaitaia, New Zealand
# KKE, Kerikeri, New Zealand
# NPE, NAPIER, New Zealand
# NPL, New Plymouth, New Zealand
# NSN, Nelson, New Zealand
# PMR, Palmerston North, New Zealand
# PPQ, Paraparaumu, New Zealand
# ROT, Rotorua, New Zealand
# TRG, Tauranga, New Zealand
# TUO, Taupo, New Zealand
# WAG, Wanganui, New Zealand
# WHK, Whakatane, New Zealand
# WRE, Whangarei, New Zealand
# ALH, Albany, Australia
# CNJ, Cloncurry, Australia
# NLK, Norfolk Island, Norfolk Island
# BQB, Brusselton, Australia
# HKK, Hokitika, New Zealand
# IVC, Invercargill, New Zealand
# EPR, Esperance, Australia
# GET, Geraldton, Australia
# IUE, Alofi, Niue
# KGI, Kalgoorlie, Australia
# KNX, Kununurra, Australia
# LEA, Learmonth, Australia
# PBO, Paraburdoo, Australia
# RVT, Ravensthorpe, Australia
# PQQ, Port Macquarie, Australia
# TIU, Timaru, New Zealand
# WSZ, Westport, New Zealand
# BVI, Birdsville, Australia
# RMA, Roma, Australia
# TWB, Toowoomba, Australia
# ISA, Mount Isa, Australia
# BUC, Burketown, Australia
# DMD, Doomadgee, Australia
# ONG, Mornington Island, Australia
# WNR, Windorah, Australia
# CMA, Cunnamulla, Australia
# SGO, St George, Australia
# XTG, Thargomindah, Australia
# EDR, Pormpuraaw, Australia
# IRG, Lockhart River, Australia
# KWM, Kowanyama, Australia
# NTN, Normanton, Australia
# WEI, Weipa, Australia
# CTL, Charlieville, Australia
# ULP, Quilpie, Australia
# YPN, Port Menier, Canada
# YNA, Natashquan, Canada
# GOU, Garoua, Cameroon
# MVR, Maroua, Cameroon
# NGE, N'gaoundere, Cameroon
# ABX, Albury, Australia
# OLP, Olympic Dam, Australia
# PLO, Port Lincoln, Australia
# ARM, Armidale, Australia
# BCI, Barcaldine, Australia
# BDB, Bundaberg, Australia
# BME, Broome, Australia
# KTA, Karratha, Australia
# EMD, Emerald, Australia
# GLT, Gladstone, Australia
# HVB, Hervey Bay, Australia
# LDH, Lord Howe Island, Australia
# MOV, Moranbah, Australia
# PHE, Port Hedland, Australia
# CFS, Coff's Harbour, Australia
# HID, Horn Island, Australia
# DBO, Dubbo, Australia
# DPO, Devonport, Australia
# MQL, Mildura, Australia
# MRZ, Moree, Australia
# ZNE, Newman, Australia
# TMW, Tamworth, Australia
# WGA, Wagga Wagga, Australia
# STD, Santo Domingo, Venezuela
# VIG, El Vigía, Venezuela
# ZVK, Savannakhet, Laos
# PKZ, Pakse, Laos
# LXG, Luang Namtha, Laos
# ODY, Muang Xay, Laos
# XKH, Phon Savan, Laos
# OSW, Orsk, Russia
# REN, Orenburg, Russia
# DYR, Anadyr, Russia
# RMI, Rimini, Italy
# PWE, Pevek, Russia
# MUN, Maturin, Venezuela
# FAE, Vagar, Faroe Islands
# AZI, Abu Dhabi, United Arab Emirates
# FJR, Fujeirah, United Arab Emirates
# XSB, Sir Bani Yas Island, United Arab Emirates
# ZDY, Dalma Island, United Arab Emirates
# AQJ, Aqaba, Jordan
# HOR, Horta, Portugal
# PIX, Pico, Portugal
# SMA, Santa Maria (island), Portugal
# TER, Lajes (terceira Island), Portugal
# CDJ, Conceicao Do Araguaia, Brazil
# CMP, Santana do Araguaia, Brazil
# GRP, Gurupi, Brazil
# MQH, Minacu, Brazil
# OIA, Ourilandia do Norte, Brazil
# RDC, Redencao, Brazil
# STZ, Santa Terezinha, Brazil
# SXO, Sao Felix do Araguaia, Brazil
# SXX, Sao Felix do Xingu, Brazil
# AAQ, Anapa, Russia
# BAX, Barnaul, Russia
# KEJ, Kemorovo, Russia
# NOZ, Novokuznetsk, Russia
# NSK, Norilsk, Russia
# OGZ, Beslan, Russia
# RGK, Gorno-Altaysk, Russia
# SIP, Simferopol, Ukraine
# STW, Stavropol, Russia
# TOF, Tomsk, Russia
# PKC, Petropavlovsk, Russia
# BEW, Beira, Mozambique
# BUQ, Bulawayo, Zimbabwe
# HDS, Hoedspruit, South Africa
# KIM, Kimberley, South Africa
# MQP, Mpumalanga, South Africa
# UTN, Upington, South Africa
# WVB, Walvis Bay, Namibia
# MSU, Maseru, Lesotho
# MTS, Manzini, Swaziland
# PHW, Phalaborwa, South Africa
# PTG, Polokwane, South Africa
# PZB, Pietermaritzburg, South Africa
# RCB, Richard's Bay, South Africa
# TET, Tete, Mozambique
# UTT, Umtata, South Africa
# VNX, Vilankulu, Mozambique
# FUT, Futuna Island, Wallis and Futuna
# WLS, Wallis, Wallis and Futuna
# HBX, Hubli, India
# IXG, Belgaum, India
# MYQ, Mysore, India
# PUG, Argyle, Australia
# BWT, Burnie, Australia
# KNS, King Island, Australia
# FLS, Flinders Island, Australia
# MEB, Melbourne, Australia
# PTJ, Portland, Australia
# CVU, Corvo, Portugal
# FLW, Flores, Portugal
# GRW, Graciosa Island, Portugal
# SJZ, Sao Jorge Island, Portugal
# AGB, Augsburg, Germany
# ERF, Erfurt, Germany
# KSF, Kassel, Germany
# CEG, Hawarden, United Kingdom
# ONQ, Zonguldak, Turkey
# XFW, Hamburg, Germany
# GDZ, Gelendzik, Russia
# ABT, El-baha, Saudi Arabia
# AJF, Al-Jawf, Saudi Arabia
# AQI, Hafr Al-batin, Saudi Arabia
# BHH, Bisha, Saudi Arabia
# EAM, Nejran, Saudi Arabia
# GIZ, Gizan, Saudi Arabia
# DWD, Dawadmi, Saudi Arabia
# EJH, Wejh, Saudi Arabia
# RAE, Arar, Saudi Arabia
# SHW, Sharurah, Saudi Arabia
# URY, Guriat, Saudi Arabia
# ULH, Al-Ula, Saudi Arabia
# RAH, Rafha, Saudi Arabia
# TUI, Turaif, Saudi Arabia
# LUD, Luderitz, Namibia
# OMD, Oranjemund, Namibia
# BRN, Bern, Switzerland
# HMA, Khanty-Mansiysk, Russia
# DIJ, Dijon, France
# PGX, Perigueux, France
# LEH, Le Havre, France
# VDA, Ovda, Israel
# TEB, Teterboro, United States
# ADF, Adiyaman, Turkey
# AJI, Agri, Turkey
# AOE, Eskissehir, Turkey
# BGG, Bingol, Turkey
# CKZ, Canakkale, Turkey
# CND, Constanta, Romania
# IGD, Igdir, Turkey
# KSY, Kars, Turkey
# TEQ, Çorlu, Turkey
# ISE, Isparta, Turkey
# KFS, Kastamonu, Turkey
# KZR, Kutahya, Turkey
# NAJ, Nakhchivan, Azerbaijan
# MCV, McArthur River Mine, Australia
# MNG, Maningrida, Australia
# ELC, Elcho Island, Australia
# MGT, Milingimbi, Australia
# VXC, Lichinga, Mozambique
# UEL, Quelimane, Mozambique
# INH, Inhambane, Mozambique
# VPY, Chimoio, Mozambique
# VXE, Sao Vicente Island, Cape Verde
# TOE, Tozeur, Tunisia
# GBB, Qabala, Azerbaijan
# LLK, Lankaran, Azerbaijan
# LWN, Gyumri, Armenia
# ACV, Arcata CA, United States
# CEC, Crescent City, United States
# AOO, Altoona, United States
# JST, Johnstown, United States
# ASE, Aspen, United States
# BFD, Bradford, United States
# JHW, Jamestown, United States
# BKW, Beckley, United States
# SHD, Weyers Cave, United States
# CIC, Chico, United States
# MGW, Morgantown, United States
# CLD, Carlsbad, United States
# DUJ, Du Bois, United States
# FKL, Franklin, United States
# PKB, PARKERSBURG, United States
# CMX, Hancock, United States
# EGE, Vail, United States
# GUC, Gunnison, United States
# HDN, Hayden, United States
# LAR, Laramie, United States
# MTJ, Montrose CO, United States
# PUB, Pueblo, United States
# EAU, Eau Claire, United States
# FOE, Topeka, United States
# ROP, Rota, Northern Mariana Islands
# TKK, Chuuk, Micronesia
# YAP, Yap, Micronesia
# HOB, Hobbs, United States
# KSA, Kosrae, Micronesia
# KWA, Kwajalein, Marshall Islands
# PNI, Pohnpei, Micronesia
# LMT, Klamath Falls, United States
# MKG, Muskegon, United States
# MOD, Modesto, United States
# PAH, PADUCAH, United States
# RDD, Redding, United States
# LPY, Le Puy, France
# MSW, Massawa, Eritrea
# GAE, Gabes, Tunisia
# GAF, Gafsa, Tunisia
# GIU, Sigiriya, Sri Lanka
# KCT, Koggala, Sri Lanka
# DIW, Dickwella, Sri Lanka
# TRR, Trinciomalee, Sri Lanka
# PED, Pardubice, Czech Republic
# AXP, Spring Point, Bahamas
# CRI, Colonel Hill, Bahamas
# IGA, Matthew Town, Bahamas
# MYG, Mayaguana, Bahamas
# NYA, Nyagan, Russia
# TBW, Tambow, Russia
# URS, Kursk, Russia
# BJZ, Badajoz, Spain
# CAJ, Canaima, Venezuela
# CUM, Cumana, Venezuela
# CZE, Coro, Venezuela
# LFR, La Fria, Venezuela
# PYH, Puerto Ayacucho, Venezuela
# SOM, San Tome, Venezuela
# SVZ, San Antonio, Venezuela
# PBL, Puerto Cabello, Venezuela
# SNV, Santa Elena de Uairen, Venezuela
# GLO, Golouchestershire, United Kingdom
# CCK, Cocos Keeling Island, Cocos (Keeling) Islands
# XCH, Christmas Island, Christmas Island
# DLI, Dalat, Vietnam
# HUI, Hue, Vietnam
# UIH, Phucat, Vietnam
# CAH, Ca Mau, Vietnam
# PXU, Pleiku, Vietnam
# DIN, Dienbienphu, Vietnam
# TBB, Tuy Hoa, Vietnam
# VCA, Can Tho, Vietnam
# VCL, Chu Lai, Vietnam
# VDH, Dong Hoi, Vietnam
# THD, Thanh Hoa, Vietnam
# VCS, Conson, Vietnam
# VKG, Rach Gia, Vietnam
# SNE, Sao Nocolau Island, Cape Verde
# AHE, Ahe, French Polynesia
# XMH, Manihi, French Polynesia
# AUQ, Hiva-oa, French Polynesia
# NHV, Nuku Hiva, French Polynesia
# UAH, Ua Huka, French Polynesia
# UAP, Ua Pou, French Polynesia
# AXR, Arutua, French Polynesia
# KKR, Kaukura Atoll, French Polynesia
# BOB, Bora Bora, French Polynesia
# HUH, Huahine Island, French Polynesia
# MAU, Maupiti, French Polynesia
# MOZ, Moorea, French Polynesia
# RFP, Raiatea Island, French Polynesia
# RGI, Rangiroa, French Polynesia
# TIH, Tikehau, French Polynesia
# FAV, Fakarava, French Polynesia
# GMR, Totegegie, French Polynesia
# HOI, Hao Island, French Polynesia
# MKP, Makemo, French Polynesia
# MVT, Mataiva, French Polynesia
# RMT, Rimatara, French Polynesia
# RUR, Rurutu, French Polynesia
# RVV, Raivavae, French Polynesia
# TKX, Takaroa, French Polynesia
# TUB, Tubuai, French Polynesia
# TKP, Takapoto, French Polynesia
# EVG, Sveg, Sweden
# HFS, Hagfors, Sweden
# KID, Kristianstad, Sweden
# MXX, Mora, Sweden
# TYF, Torsby, Sweden
# PJA, Pajala, Sweden
# MHG, Mannheim, Germany
# URE, Kuressaare, Estonia
# VIN, Vinnitsa, Ukraine
# BNI, Benin, Nigeria
# CBQ, Calabar, Nigeria
# IBA, Ibadan, Nigeria
# ILR, Ilorin, Nigeria
# QOW, Imo, Nigeria
# QRW, Osubi, Nigeria
# SKO, Sokoto, Nigeria
# YOL, Yola, Nigeria
# JOS, Jos, Nigeria
# KAD, Kaduna, Nigeria
# ANS, Andahuaylas, Peru
# ATA, Anta, Peru
# ARW, Arad, Romania
# CRA, Craiova, Romania
# DEB, Debrecen, Hungary
# KET, Kengtung, Burma
# KYP, Kyaukpyu, Burma
# MYT, Myitkyina, Burma
# PBU, Putao, Burma
# KME, Kamembe, Rwanda
# HFT, Hammerfest, Norway
# LKL, Lakselv, Norway
# SOJ, Sorkjosen, Norway
# VDS, Vadso, Norway
# ANX, Andoya, Norway
# BNN, Bronnoysund, Norway
# FDE, Forde, Norway
# FRO, Floro, Norway
# HOV, Orsta-Volda, Norway
# SKE, Skien, Norway
# SOG, Sogndal, Norway
# BJF, Batsfjord, Norway
# BVG, Berlevag, Norway
# MEH, Mehamn, Norway
# VAW, Vardø, Norway
# MQN, Mo i Rana, Norway
# SSJ, Sandnessjoen, Norway
# LKN, Leknes, Norway
# MJF, Mosjoen, Norway
# NVK, Narvik, Norway
# RET, Røst, Norway
# SKN, Stokmarknes, Norway
# SVJ, Svolvær, Norway
# HAA, Hasvik, Norway
# HVG, Honningsvag, Norway
# OSY, Namsos, Norway
# RVK, Rørvik, Norway
# RRS, Roros, Norway
# SDN, Sandane, Norway
# YIF, St-Augustin, Canada
# YHR, Chevery, Canada
# ZTB, Tête-à-la-Baleine, Canada
# ZLT, La Tabatière, Canada
# YRG, Rigolet, Canada
# ZKG, Kegaska, Canada
# EUX, Oranjestad, Netherlands Antilles
# SAB, Saba, Netherlands Antilles
# YBR, Brandon, Canada
# YHM, Hamilton, Canada
# YXX, Abbotsford, Canada
# KEW, Keewaywin, Canada
# KIF, Kingfisher Lake, Canada
# WNN, Wunnumin Lake, Canada
# MSA, Muskrat Dam, Canada
# XBE, Bearskin Lake, Canada
# ZPB, Sachigo Lake, Canada
# ZRJ, Round Lake, Canada
# SUR, Summer Beaver, Canada
# YAX, Angling Lake, Canada
# YTL, Big Trout Lake, Canada
# XKS, Kasabonika, Canada
# YAC, Cat Lake, Canada
# YER, Fort Severn, Canada
# YFH, Fort Hope, Canada
# YLH, Lansdowne House, Canada
# YOG, Ogoki Post, Canada
# YHP, Poplar Hill, Canada
# YNO, North Spirit Lake, Canada
# YWP, Webequie, Canada
# YPL, Pickle Lake, Canada
# YPM, Pikangikum, Canada
# YVZ, Deer Lake, Canada
# ZSJ, Sandy Lake, Canada
# KHS, Khasab, Oman
# ZQW, Zweibruecken, Germany
# EXI, Excursion Inlet, United States
# KAE, Kake, United States
# APF, Naples, United States
# UPN, Uruapan, Mexico
# IAA, Igarka, Russia
# MRX, Bandar Mahshahr, Iran
# NOJ, Noyabrsk, Russia
# KGP, Kogalym, Russia
# YAT, Attawapiskat, Canada
# YPO, Peawanuck, Canada
# ZKE, Kashechewan, Canada
# YFA, Fort Albany, Canada
# YMO, Moosonee, Canada
# YKU, Chisasibi, Canada
# YKQ, Waskaganish, Canada
# YMT, Chibougamau, Canada
# YNS, Nemiscau, Canada
# ZEM, Eastmain River, Canada
# YNC, Wemindji, Canada
# MCM, Monaco, Monaco
# GCN, Grand Canyon, United States
# BDP, Chandragarhi, Nepal
# BHR, Bharatpur, Nepal
# BIR, Biratnagar, Nepal
# BWA, Bhairawa, Nepal
# DHI, Dhangarhi, Nepal
# KEP, Nepalgunj, Nepal
# PKR, Pokhara, Nepal
# TMI, Tumling Tar, Nepal
# UKS, Sevastopol, Ukraine
# RBQ, Rerrenabaque, Bolivia
# UYU, Uyuni, Bolivia
# BFF, Scottsbluff, United States
# CEZ, Cortez, United States
# EAR, Kearney, United States
# LBF, North Platte, United States
# MCK, McCook, United States
# RIW, Riverton WY, United States
# SHR, Sheridan, United States
# MCE, Merced, United States
# PRC, Prescott, United States
# VIS, Visalia, United States
# SVC, Silver City, United States
# BHQ, Broken Hill, Australia
# CED, Ceduna, Australia
# CPD, Coober Pedy, Australia
# KGC, Kingscote, Australia
# MGB, Mount Gambier, Australia
# WYA, Whyalla, Australia
# BHS, Bathurst, Australia
# PKE, Parkes, Australia
# GFF, Griffith, Australia
# NRA, Narrandera, Australia
# GFN, Grafton, Australia
# TRO, Taree, Australia
# JCK, Julia Creek, Australia
# RCM, Richmond, Australia
# WIN, Winton, Australia
# LSY, Lismore, Australia
# MIM, Merimbula, Australia
# MYA, Moruya, Australia
# OAG, Orange, Australia
#
# SPB, San Luis, United States
# SSB, Christiansted, Virgin Islands
#
# AKB, Atka, United States
# DUT, Unalaska, United States
# IKO, Nikolski, United States
# KQA, Akutan, United States
#
# BLD, Boulder City, United States
# GCW, Grand Canyon West, United States
#
# BFI, Seattle, United States
# CLM, Port Angeles, United States
# ESD, Eastsound, United States
# FRD, Friday Harbor, United States
#
# ERS, Windhoek, Namibia
# MPA, Mpacha, Namibia
# NDU, Rundu, Namibia
# OND, Ondangwa, Namibia
#
# BMY, Waala, New Caledonia
# GEA, Noumea, New Caledonia
# KOC, Koumac, New Caledonia
# ILP, Île des Pins, New Caledonia
# KNQ, Kone, New Caledonia
# LIF, Lifou, New Caledonia
# MEE, Mare, New Caledonia
# TGJ, Tiga, New Caledonia
# TOU, Touho, New Caledonia
# UVE, Ouvea, New Caledonia
